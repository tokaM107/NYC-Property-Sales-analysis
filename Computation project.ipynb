# %% [markdown]
# ## Import neccessany libararies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data import

# %%
df = pd.read_csv("nyc-rolling-sales.csv")
df.head(10)
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
# 5           9        1  ALPHABET CITY
# 6          10        1  ALPHABET CITY
# 7          11        1  ALPHABET CITY
# 8          12        1  ALPHABET CITY
# 9          13        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
# 5  07 RENTALS - WALKUP APARTMENTS                                 2    405
# 6  07 RENTALS - WALKUP APARTMENTS                                2B    406
# 7  07 RENTALS - WALKUP APARTMENTS                                 2    407
# 8  08 RENTALS - ELEVATOR APARTMENTS                               2    379
# 9  08 RENTALS - ELEVATOR APARTMENTS                               2    387
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# 2   39                                  C7   197 EAST 3RD   STREET  ...
# 3   21                                  C4     154 EAST 7TH STREET  ...
# 4   55                                  C2  301 EAST 10TH   STREET  ...
# 5   16                                  C4  516 EAST 12TH   STREET  ...
# 6   32                                  C4            210 AVENUE B  ...
# 7   18                                  C7  520 EAST 14TH   STREET  ...
# 8   34                                  D5            141 AVENUE D  ...
# 9  153                                  D9     629 EAST 5TH STREET  ...
#
#   RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                 5                 0            5              1633
# 1                28                 3           31              4616
# 2                16                 1           17              2212
# 3                10                 0           10              2272
# 4                 6                 0            6              2369
# 5                20                 0           20              2581
# 6                 8                 0            8              1750
# 7                44                 2           46              5163
# 8                15                 0           15              1534
# 9                24                 0           24              4489
#
#    GROSS SQUARE FEET YEAR BUILT TAX CLASS AT TIME OF SALE  \
# 0               6440       1900                         2
# 1              18690       1900                         2
# 2               7803       1900                         2
# 3               6794       1913                         2
# 4               4615       1900                         2
# 5               9730       1900                         2
# 6               4226       1920                         2
# 7              21007       1900                         2
# 8               9198       1920                         2
# 9              18523       1920                         2
#
#    BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
# 0                              C2     6625000  2017-07-19 00:00:00
# 1                              C7         -    2016-12-14 00:00:00
# 2                              C7         -    2016-12-09 00:00:00
# 3                              C4     3936272  2016-09-23 00:00:00
# 4                              C2     8000000  2016-11-17 00:00:00
# 5                              C4         -    2017-07-20 00:00:00
# 6                              C4     3192840  2016-09-23 00:00:00
# 7                              C7         -    2017-07-20 00:00:00
# 8                              D5         -    2017-06-20 00:00:00
# 9                              D9    16232000  2016-11-07 00:00:00
#
# [10 rows x 22 columns]

# %% [markdown]
# ## Data exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      84548 non-null  int64
#  1   BOROUGH                         84548 non-null  int64
#  2   NEIGHBORHOOD                    84548 non-null  object
#  3   BUILDING CLASS CATEGORY         84548 non-null  object
#  4   TAX CLASS AT PRESENT            84548 non-null  object
#  5   BLOCK                           84548 non-null  int64
#  6   LOT                             84548 non-null  int64
#  7   EASE-MENT                       84548 non-null  object
#  8   BUILDING CLASS AT PRESENT       84548 non-null  object
#  9   ADDRESS                         84548 non-null  object
#  10  APARTMENT NUMBER                84548 non-null  object
#  11  ZIP CODE                        84548 non-null  int64
#  12  RESIDENTIAL UNITS               84548 non-null  int64
#  13  COMMERCIAL UNITS                84548 non-null  int64
#  14  TOTAL UNITS                     84548 non-null  int64
#  15  LAND SQUARE FEET                84548 non-null  object
#  16  GROSS SQUARE FEET               84548 non-null  object
#  17  YEAR BUILT                      84548 non-null  int64
#  18  TAX CLASS AT TIME OF SALE       84548 non-null  int64
#  19  BUILDING CLASS AT TIME OF SALE  84548 non-null  object
#  20  SALE PRICE                      84548 non-null  object
#  21  SALE DATE                       84548 non-null  object
# dtypes: int64(10), object(12)
# memory usage: 14.2+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                        0
# BOROUGH                           0
# NEIGHBORHOOD                      0
# BUILDING CLASS CATEGORY           0
# TAX CLASS AT PRESENT              0
# BLOCK                             0
# LOT                               0
# EASE-MENT                         0
# BUILDING CLASS AT PRESENT         0
# ADDRESS                           0
# APARTMENT NUMBER                  0
# ZIP CODE                          0
# RESIDENTIAL UNITS                 0
# COMMERCIAL UNITS                  0
# TOTAL UNITS                       0
# LAND SQUARE FEET                  0
# GROSS SQUARE FEET                 0
# YEAR BUILT                        0
# TAX CLASS AT TIME OF SALE         0
# BUILDING CLASS AT TIME OF SALE    0
# SALE PRICE                        0
# SALE DATE                         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#          Unnamed: 0       BOROUGH         BLOCK           LOT      ZIP CODE  \
# count  84548.000000  84548.000000  84548.000000  84548.000000  84548.000000
# mean   10344.359878      2.998758   4237.218976    376.224015  10731.991614
# std     7151.779436      1.289790   3568.263407    658.136814   1290.879147
# min        4.000000      1.000000      1.000000      1.000000      0.000000
# 25%     4231.000000      2.000000   1322.750000     22.000000  10305.000000
# 50%     8942.000000      3.000000   3311.000000     50.000000  11209.000000
# 75%    15987.250000      4.000000   6281.000000   1001.000000  11357.000000
# max    26739.000000      5.000000  16322.000000   9106.000000  11694.000000
#
#        RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS    YEAR BUILT  \
# count       84548.000000      84548.000000  84548.000000  84548.000000
# mean            2.025264          0.193559      2.249184   1789.322976
# std            16.721037          8.713183     18.972584    537.344993
# min             0.000000          0.000000      0.000000      0.000000
# 25%             0.000000          0.000000      1.000000   1920.000000
# 50%             1.000000          0.000000      1.000000   1940.000000
# 75%             2.000000          0.000000      2.000000   1965.000000
# max          1844.000000       2261.000000   2261.000000   2017.000000
#
#        TAX CLASS AT TIME OF SALE
# count               84548.000000
# mean                    1.657485
# std                     0.819341
# min                     1.000000
# 25%                     1.000000
# 50%                     2.000000
# 75%                     2.000000
# max                     4.000000

# %%
print("--- Unique Value Counts for Each Column ---")
for col in df.columns:
    unique_values = df[col].unique()
    num_unique = len(unique_values)
    print(f"\nColumn: {col}")
    print(f"  Number of Unique Values: {num_unique}")
    if num_unique < 20:  # Display the unique values if the count is relatively small
        print(f"  Unique Values: {unique_values}")
    else:
        print("  (Too many unique values to display all)")
# Out:
# --- Unique Value Counts for Each Column ---
#
# Column: Unnamed: 0
#   Number of Unique Values: 26736
#   (Too many unique values to display all)
#
# Column: BOROUGH
#   Number of Unique Values: 5
#   Unique Values: [1 2 3 4 5]
#
# Column: NEIGHBORHOOD
#   Number of Unique Values: 254
#   (Too many unique values to display all)
#
# Column: BUILDING CLASS CATEGORY
#   Number of Unique Values: 47
#   (Too many unique values to display all)
#
# Column: TAX CLASS AT PRESENT
#   Number of Unique Values: 11
#   Unique Values: ['2A' '2' '2B' '2C' ' ' '4' '1' '1C' '3' '1A' '1B']
#
# Column: BLOCK
#   Number of Unique Values: 11566
#   (Too many unique values to display all)
#
# Column: LOT
#   Number of Unique Values: 2627
#   (Too many unique values to display all)
#
# Column: EASE-MENT
#   Number of Unique Values: 1
#   Unique Values: [' ']
#
# Column: BUILDING CLASS AT PRESENT
#   Number of Unique Values: 167
#   (Too many unique values to display all)
#
# Column: ADDRESS
#   Number of Unique Values: 67563
#   (Too many unique values to display all)
#
# Column: APARTMENT NUMBER
#   Number of Unique Values: 3989
#   (Too many unique values to display all)
#
# Column: ZIP CODE
#   Number of Unique Values: 186
#   (Too many unique values to display all)
#
# Column: RESIDENTIAL UNITS
#   Number of Unique Values: 176
#   (Too many unique values to display all)
#
# Column: COMMERCIAL UNITS
#   Number of Unique Values: 55
#   (Too many unique values to display all)
#
# Column: TOTAL UNITS
#   Number of Unique Values: 192
#   (Too many unique values to display all)
#
# Column: LAND SQUARE FEET
#   Number of Unique Values: 6062
#   (Too many unique values to display all)
#
# Column: GROSS SQUARE FEET
#   Number of Unique Values: 5691
#   (Too many unique values to display all)
#
# Column: YEAR BUILT
#   Number of Unique Values: 158
#   (Too many unique values to display all)
#
# Column: TAX CLASS AT TIME OF SALE
#   Number of Unique Values: 4
#   Unique Values: [2 4 1 3]
#
# Column: BUILDING CLASS AT TIME OF SALE
#   Number of Unique Values: 166
#   (Too many unique values to display all)
#
# Column: SALE PRICE
#   Number of Unique Values: 10008
#   (Too many unique values to display all)
#
# Column: SALE DATE
#   Number of Unique Values: 364
#   (Too many unique values to display all)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df['SALE DATE'] = pd.to_datetime(df['SALE DATE'], errors='coerce')
numeric_cols_eda = ['SALE PRICE', 'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT']
for col in numeric_cols_eda:
    df[col] = pd.to_numeric(df[col], errors='coerce')
df.replace([float('inf'), -float('inf')], pd.NA, inplace=True)

# %%
print("--- Initial Data Overview for EDA ---")
df.head()
# Out:
# --- Initial Data Overview for EDA ---
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# 2   39                                  C7   197 EAST 3RD   STREET  ...
# 3   21                                  C4     154 EAST 7TH STREET  ...
# 4   55                                  C2  301 EAST 10TH   STREET  ...
#
#   RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                 5                 0            5            1633.0
# 1                28                 3           31            4616.0
# 2                16                 1           17            2212.0
# 3                10                 0           10            2272.0
# 4                 6                 0            6            2369.0
#
#    GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0             6440.0        1900                          2
# 1            18690.0        1900                          2
# 2             7803.0        1900                          2
# 3             6794.0        1913                          2
# 4             4615.0        1900                          2
#
#    BUILDING CLASS AT TIME OF SALE  SALE PRICE  SALE DATE
# 0                              C2   6625000.0 2017-07-19
# 1                              C7         NaN 2016-12-14
# 2                              C7         NaN 2016-12-09
# 3                              C4   3936272.0 2016-09-23
# 4                              C2   8000000.0 2016-11-17
#
# [5 rows x 22 columns]

# %%
print("\n--- Dataset Information ---")
df.info()
# Out:
# --- Dataset Information ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      84548 non-null  int64
#  1   BOROUGH                         84548 non-null  int64
#  2   NEIGHBORHOOD                    84548 non-null  object
#  3   BUILDING CLASS CATEGORY         84548 non-null  object
#  4   TAX CLASS AT PRESENT            84548 non-null  object
#  5   BLOCK                           84548 non-null  int64
#  6   LOT                             84548 non-null  int64
#  7   EASE-MENT                       84548 non-null  object
#  8   BUILDING CLASS AT PRESENT       84548 non-null  object
#  9   ADDRESS                         84548 non-null  object
#  10  APARTMENT NUMBER                84548 non-null  object
#  11  ZIP CODE                        84548 non-null  int64
#  12  RESIDENTIAL UNITS               84548 non-null  int64
#  13  COMMERCIAL UNITS                84548 non-null  int64
#  14  TOTAL UNITS                     84548 non-null  int64
#  15  LAND SQUARE FEET                58296 non-null  float64
#  16  GROSS SQUARE FEET               56936 non-null  float64
#  17  YEAR BUILT                      84548 non-null  int64
#  18  TAX CLASS AT TIME OF SALE       84548 non-null  int64
#  19  BUILDING CLASS AT TIME OF SALE  84548 non-null  object
#  20  SALE PRICE                      69987 non-null  float64
#  21  SALE DATE                       84548 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(10), object(8)
# memory usage: 14.2+ MB

# %%
print("\n--- Descriptive Statistics for Key Numerical Features ---")
df[numeric_cols_eda].describe()
# Out:
# --- Descriptive Statistics for Key Numerical Features ---
#          SALE PRICE  LAND SQUARE FEET  GROSS SQUARE FEET    YEAR BUILT
# count  6.998700e+04      5.829600e+04       5.693600e+04  84548.000000
# mean   1.276456e+06      3.941676e+03       4.045707e+03   1789.322976
# std    1.140526e+07      4.198397e+04       3.503249e+04    537.344993
# min    0.000000e+00      0.000000e+00       0.000000e+00      0.000000
# 25%    2.250000e+05      1.650000e+03       1.046750e+03   1920.000000
# 50%    5.300000e+05      2.325000e+03       1.680000e+03   1940.000000
# 75%    9.500000e+05      3.500000e+03       2.560000e+03   1965.000000
# max    2.210000e+09      4.252327e+06       3.750565e+06   2017.000000

# %%
df.isna().sum().sum()
# Out:
# 68425

# %%
df.isna().sum()
# Out:
# Unnamed: 0                            0
# BOROUGH                               0
# NEIGHBORHOOD                          0
# BUILDING CLASS CATEGORY               0
# TAX CLASS AT PRESENT                  0
# BLOCK                                 0
# LOT                                   0
# EASE-MENT                             0
# BUILDING CLASS AT PRESENT             0
# ADDRESS                               0
# APARTMENT NUMBER                      0
# ZIP CODE                              0
# RESIDENTIAL UNITS                     0
# COMMERCIAL UNITS                      0
# TOTAL UNITS                           0
# LAND SQUARE FEET                  26252
# GROSS SQUARE FEET                 27612
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                        14561
# SALE DATE                             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                            0
# BOROUGH                               0
# NEIGHBORHOOD                          0
# BUILDING CLASS CATEGORY               0
# TAX CLASS AT PRESENT                  0
# BLOCK                                 0
# LOT                                   0
# EASE-MENT                             0
# BUILDING CLASS AT PRESENT             0
# ADDRESS                               0
# APARTMENT NUMBER                      0
# ZIP CODE                              0
# RESIDENTIAL UNITS                     0
# COMMERCIAL UNITS                      0
# TOTAL UNITS                           0
# LAND SQUARE FEET                  26252
# GROSS SQUARE FEET                 27612
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                        14561
# SALE DATE                             0
# dtype: int64

# %%
print("\n--- Unique Value Counts for Key Categorical Features ---")
categorical_cols_eda = ['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY', 'TAX CLASS AT TIME OF SALE']
for col in categorical_cols_eda:
    print(f"\nColumn: {col}")
    print(f"  Number of Unique Values: {df[col].nunique()}")
    if df[col].nunique() < 15:
        print(f"  Unique Values: {df[col].unique()}")
# Out:
# --- Unique Value Counts for Key Categorical Features ---
#
# Column: BOROUGH
#   Number of Unique Values: 5
#   Unique Values: [1 2 3 4 5]
#
# Column: NEIGHBORHOOD
#   Number of Unique Values: 254
#
# Column: BUILDING CLASS CATEGORY
#   Number of Unique Values: 47
#
# Column: TAX CLASS AT TIME OF SALE
#   Number of Unique Values: 4
#   Unique Values: [2 4 1 3]

# %%
# --- Visualizing Distributions using For Loops ---

print("\n--- Visualizing Distributions ---")

# Histograms for numerical features
for col in numeric_cols_eda:
    plt.figure(figsize=(12, 6))
    sns.histplot(df[col].dropna(), kde=True, bins=50)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# --- Count plots for categorical features (with improvements) ---
categorical_cols_eda = ['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY', 'TAX CLASS AT TIME OF SALE']
top_n = 50  # Choose the top N categories to display for 'BUILDING CLASS CATEGORY'

for col in categorical_cols_eda:
    plt.figure(figsize=(12, 7))  # Increased figure size for better readability
    if df[col].nunique() > top_n:
        top_categories = df[col].value_counts().nlargest(top_n).index
        sns.countplot(y=df[df[col].isin(top_categories)][col],
                      order=top_categories)
        plt.title(f'Count of Properties by Top {top_n} {col}')
    else:
        sns.countplot(y=df[col], order=df[col].value_counts().index)
        plt.title(f'Count of Properties by {col}')
    plt.xlabel('Count')
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()
# Out:
# --- Visualizing Distributions ---

# %%
neighborhood_counts = df['NEIGHBORHOOD'].value_counts().sort_values(ascending=False)
print("Count of Properties by Neighborhood:")
print(neighborhood_counts)
# Out:
# Count of Properties by Neighborhood:
# NEIGHBORHOOD
# FLUSHING-NORTH              3068
# UPPER EAST SIDE (59-79)     1736
# UPPER EAST SIDE (79-96)     1590
# UPPER WEST SIDE (59-79)     1439
# BEDFORD STUYVESANT          1436
#                             ...
# FRESH KILLS                    2
# BRONX PARK                     1
# PELHAM BAY                     1
# EAST RIVER                     1
# CITY ISLAND-PELHAM STRIP       1
# Name: count, Length: 254, dtype: int64

# %%
# --- Visualizing Relationships using For Loops ---

print("\n--- Visualizing Relationships ---")

# Scatter plots for numerical pairs (Sale Price vs. others)
for col in numeric_cols_eda[1:]:  # Exclude Sale Price vs. itself
    plt.figure(figsize=(12, 8))
    sns.scatterplot(x=col, y='SALE PRICE', data=df, alpha=0.3)  # Added data=df
    plt.title(f'Sale Price vs. {col}')
    plt.xlabel(col)
    plt.ylabel('Sale Price')
    plt.show()
    plt.show()
# Out:
# --- Visualizing Relationships ---

# %%
# --- Bar plots for Sale Price vs. categorical features in subplots ---
categorical_cols_eda = df.select_dtypes(include='object').columns
top_n = 50  # Choose the top N categories to display for high-cardinality features

for col in categorical_cols_eda:
    plt.figure(figsize=(18, 8))  # Adjust figure size for two subplots

    # Subplot 1: Bar Plot of Average Sale Price
    plt.subplot(1, 2, 1)  # 1 row, 2 columns, first subplot
    if df[col].nunique() > top_n:
        top_categories = df[col].value_counts().nlargest(top_n).index
        avg_price = df[df[col].isin(top_categories)].groupby(col)['SALE PRICE'].mean().sort_values(ascending=False)
        sns.barplot(x=avg_price.index, y=avg_price.values)
        plt.title(f'Average Sale Price by Top {top_n} {col}')
        plt.xticks(rotation=90, ha='right', fontsize=8)
        plt.ylabel('Average Sale Price')
        plt.xlabel(col)
    else:
        avg_price = df.groupby(col)['SALE PRICE'].mean().sort_values(ascending=False)
        sns.barplot(x=avg_price.index, y=avg_price.values)
        plt.title(f'Average Sale Price by {col}')
        plt.xticks(rotation=90, ha='right')
        plt.ylabel('Average Sale Price')
        plt.xlabel(col)

    # Subplot 2: Count Plot
    plt.subplot(1, 2, 2)  # 1 row, 2 columns, second subplot
    if df[col].nunique() > top_n:
        top_categories = df[col].value_counts().nlargest(top_n).index
        sns.countplot(y=df[df[col].isin(top_categories)][col], order=top_categories)
        plt.title(f'Count of Top {top_n} {col}')
        plt.ylabel(col)
        plt.xlabel('Count')
        plt.yticks([]) # Remove y-axis ticks for count plot as labels are on the left
    else:
        sns.countplot(y=df[col], order=df[col].value_counts().index)
        plt.title(f'Count of {col}')
        plt.ylabel(col)
        plt.xlabel('Count')
        plt.yticks([]) # Remove y-axis ticks for count plot

    plt.tight_layout()
    plt.show()

# %%
# --- Visualizing Trends ---

print("\n--- Visualizing Trends ---")

# Average Sale Price Over Time
sales_over_time = df.groupby(pd.Grouper(key='SALE DATE', freq='ME'))['SALE PRICE'].mean()
plt.figure(figsize=(12, 6))
sales_over_time.plot()
plt.title('Average Sale Price Over Time')
plt.xlabel('Sale Date')
plt.ylabel('Average Sale Price')
plt.grid(True)
plt.show()

# Number of Sales Over Time
sales_count_over_time = df.groupby(pd.Grouper(key='SALE DATE', freq='ME')).size()
plt.figure(figsize=(12, 6))
sales_count_over_time.plot()
plt.title('Number of Sales Over Time')
plt.xlabel('Sale Date')
plt.ylabel('Number of Sales')
plt.grid(True)
plt.show()
# Out:
# --- Visualizing Trends ---

# %%
print("\n--- Summary of EDA - Focus on Patterns, Anomalies, Trends, and Relationships ---")
print("- Examine the generated plots to understand the data characteristics.")
print("- Look for patterns in distributions and relationships between variables.")
print("- Identify potential outliers through visualizations like histograms and box plots.")
print("- Observe any trends in sale price and sales volume over time.")
print("- Document your findings based on the visual analysis.")
# Out:
# --- Summary of EDA - Focus on Patterns, Anomalies, Trends, and Relationships ---
# - Examine the generated plots to understand the data characteristics.
# - Look for patterns in distributions and relationships between variables.
# - Identify potential outliers through visualizations like histograms and box plots.
# - Observe any trends in sale price and sales volume over time.
# - Document your findings based on the visual analysis.

# %%
# --- Function to detect outliers using IQR ---
def detect_outliers_iqr(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = series[(series < lower_bound) | (series > upper_bound)]
    return outliers

# --- Calculate and Visualize Outliers ---
print("\n--- Outlier Analysis ---")
for col in numeric_cols_eda:
    plt.figure(figsize=(10, 6))
    sns.boxplot(y=df[col])
    plt.title(f'Box Plot of {col} (Outliers as Individual Points)')
    plt.ylabel(col)
    plt.show()

    outliers = detect_outliers_iqr(df[col])
    num_outliers = len(outliers)
    total_data_points = len(df[col])
    percentage_outliers = (num_outliers / total_data_points) * 100

    print(f"\nColumn: {col}")
    print(f"  Number of outliers: {num_outliers}")
    print(f"  Percentage of outliers: {percentage_outliers:.2f}%")
    if num_outliers > 0:
        print(f"  First few outlier values:\n{outliers.head()}")
    else:
        print("  No outliers detected.")
# Out:
# --- Outlier Analysis ---
# Column: SALE PRICE
#   Number of outliers: 6652
#   Percentage of outliers: 7.87%
#   First few outlier values:
# 0     6625000.0
# 3     3936272.0
# 4     8000000.0
# 6     3192840.0
# 9    16232000.0
# Name: SALE PRICE, dtype: float64
# Column: LAND SQUARE FEET
#   Number of outliers: 3571
#   Percentage of outliers: 4.22%
#   First few outlier values:
# 75     33650.0
# 196    32246.0
# 235    12344.0
# 239    10053.0
# 929     6468.0
# Name: LAND SQUARE FEET, dtype: float64
# Column: GROSS SQUARE FEET
#   Number of outliers: 4179
#   Percentage of outliers: 4.94%
#   First few outlier values:
# 0     6440.0
# 1    18690.0
# 2     7803.0
# 3     6794.0
# 5     9730.0
# Name: GROSS SQUARE FEET, dtype: float64
# Column: YEAR BUILT
#   Number of outliers: 7038
#   Percentage of outliers: 8.32%
#   First few outlier values:
# 74    0
# 76    0
# 77    0
# 78    0
# 87    0
# Name: YEAR BUILT, dtype: int64

# %%
# --- Calculate the percentage of each value for all columns ---
print("\n--- Percentage of Each Value in Each Column ---")
for col in df.columns:
    print(f"\nColumn: {col}")
    value_counts = df[col].value_counts(dropna=False) # Include NaN if present
    percentages = (value_counts / len(df)) * 100
    print(percentages)
# Out:
# --- Percentage of Each Value in Each Column ---
#
# Column: Unnamed: 0
# Unnamed: 0
# 4        0.005914
# 4699     0.005914
# 4710     0.005914
# 4709     0.005914
# 4708     0.005914
#            ...
# 24948    0.001183
# 24949    0.001183
# 24950    0.001183
# 24951    0.001183
# 26739    0.001183
# Name: count, Length: 26736, dtype: float64
#
# Column: BOROUGH
# BOROUGH
# 4    31.622274
# 3    28.441832
# 1    21.651606
# 5     9.947012
# 2     8.337276
# Name: count, dtype: float64
#
# Column: NEIGHBORHOOD
# NEIGHBORHOOD
# FLUSHING-NORTH              3.628708
# UPPER EAST SIDE (59-79)     2.053272
# UPPER EAST SIDE (79-96)     1.880589
# UPPER WEST SIDE (59-79)     1.701992
# BEDFORD STUYVESANT          1.698443
#                               ...
# FRESH KILLS                 0.002366
# BRONX PARK                  0.001183
# PELHAM BAY                  0.001183
# EAST RIVER                  0.001183
# CITY ISLAND-PELHAM STRIP    0.001183
# Name: count, Length: 254, dtype: float64
#
# Column: BUILDING CLASS CATEGORY
# BUILDING CLASS CATEGORY
# 01 ONE FAMILY DWELLINGS                         21.567630
# 02 TWO FAMILY DWELLINGS                         18.720727
# 13 CONDOS - ELEVATOR APARTMENTS                 15.362871
# 10 COOPS - ELEVATOR APARTMENTS                  15.259971
# 03 THREE FAMILY DWELLINGS                        5.185220
# 07 RENTALS - WALKUP APARTMENTS                   4.099446
# 09 COOPS - WALKUP APARTMENTS                     3.272697
# 04 TAX CLASS 1 CONDOS                            1.958651
# 44 CONDO PARKING                                 1.704357
# 15 CONDOS - 2-10 UNIT RESIDENTIAL                1.515116
# 05 TAX CLASS 1 VACANT LAND                       1.476085
# 17 CONDO COOPS                                   1.420495
# 22 STORE BUILDINGS                               1.105881
# 12 CONDOS - WALKUP APARTMENTS                    1.095236
# 14 RENTALS - 4-10 UNIT                           0.793632
# 29 COMMERCIAL GARAGES                            0.694280
# 43 CONDO OFFICE BUILDINGS                        0.561811
# 31 COMMERCIAL VACANT LAND                        0.547618
# 08 RENTALS - ELEVATOR APARTMENTS                 0.451814
# 47 CONDO NON-BUSINESS STORAGE                    0.445901
# 21 OFFICE BUILDINGS                              0.413966
# 30 WAREHOUSES                                    0.385580
# 45 CONDO HOTELS                                  0.249562
# 27 FACTORIES                                     0.237735
# 06 TAX CLASS 1 - OTHER                           0.215262
# 41 TAX CLASS 4 - OTHER                           0.186876
# 46 CONDO STORE BUILDINGS                         0.182145
# 26 OTHER HOTELS                                  0.134835
# 37 RELIGIOUS FACILITIES                          0.118276
# 16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT       0.113545
# 33 EDUCATIONAL FACILITIES                        0.081610
# 32 HOSPITAL AND HEALTH FACILITIES                0.069783
# 48 CONDO TERRACES/GARDENS/CABANAS                0.055590
# 23 LOFT BUILDINGS                                0.054407
# 11A CONDO-RENTALS                                0.050859
# 35 INDOOR PUBLIC AND CULTURAL FACILITIES         0.037848
# 49 CONDO WAREHOUSES/FACTORY/INDUS                0.035483
# 28 COMMERCIAL CONDOS                             0.035483
# 38 ASYLUMS AND HOMES                             0.029569
# 36 OUTDOOR RECREATIONAL FACILITIES               0.016559
# 42 CONDO CULTURAL/MEDICAL/EDUCATIONAL/ETC        0.015376
# 34 THEATRES                                      0.014193
# 25 LUXURY HOTELS                                 0.014193
# 18 TAX CLASS 3 - UNTILITY PROPERTIES             0.004731
# 40 SELECTED GOVERNMENTAL FACILITIES              0.002366
# 11 SPECIAL CONDO BILLING LOTS                    0.002366
# 39 TRANSPORTATION FACILITIES                     0.002366
# Name: count, dtype: float64
#
# Column: TAX CLASS AT PRESENT
# TAX CLASS AT PRESENT
# 1     45.693571
# 2     36.569759
# 4      7.262147
# 2A     2.981738
# 2C     2.264986
# 1A     1.707906
# 1B     1.459526
# 2B     0.962767
#        0.872877
# 1C     0.219993
# 3      0.004731
# Name: count, dtype: float64
#
# Column: BLOCK
# BLOCK
# 5066     0.477835
# 16       0.301604
# 2135     0.249562
# 4978     0.221176
# 1171     0.214080
#            ...
# 9410     0.001183
# 9273     0.001183
# 9528     0.001183
# 9556     0.001183
# 13959    0.001183
# Name: count, Length: 11566, dtype: float64
#
# Column: LOT
# LOT
# 1       4.878885
# 20      1.162653
# 12      1.149643
# 40      1.105881
# 23      1.077494
#           ...
# 2878    0.001183
# 2923    0.001183
# 3191    0.001183
# 3292    0.001183
# 679     0.001183
# Name: count, Length: 2627, dtype: float64
#
# Column: EASE-MENT
# EASE-MENT
#     100.0
# Name: count, dtype: float64
#
# Column: BUILDING CLASS AT PRESENT
# BUILDING CLASS AT PRESENT
# D4    14.977291
# R4    14.763211
# A1     7.987179
# A5     6.721626
# B2     5.822728
#         ...
# R7     0.001183
# P7     0.001183
# HH     0.001183
# M2     0.001183
# Z7     0.001183
# Name: count, Length: 167, dtype: float64
#
# Column: ADDRESS
# ADDRESS
# 131-05 40TH   ROAD        0.248380
# 429 KENT AVENUE           0.186876
# 169 WEST 95TH   STREET    0.180962
# 131-03 40TH   ROAD        0.173866
# 265 STATE STREET          0.150211
#                             ...
# 9405 SEAVIEW AVENUE       0.001183
# 9410 AVENUE N             0.001183
# 9911 SEAVIEW AVENUE       0.001183
# 1471 EAST 99TH STREET     0.001183
# 155 CLAY PIT ROAD         0.001183
# Name: count, Length: 67563, dtype: float64
#
# Column: APARTMENT NUMBER
# APARTMENT NUMBER
#         77.466055
# 4        0.352463
# 3A       0.348914
# 2        0.325259
# 3B       0.325259
#           ...
# ST50     0.001183
# ST54     0.001183
# SU13     0.001183
# SU21     0.001183
# 363      0.001183
# Name: count, Length: 3989, dtype: float64
#
# Column: ZIP CODE
# ZIP CODE
# 10314    1.995316
# 11354    1.636940
# 11201    1.565974
# 11235    1.551781
# 11234    1.377916
#            ...
# 10105    0.005914
# 11430    0.001183
# 10281    0.001183
# 10803    0.001183
# 10167    0.001183
# Name: count, Length: 186, dtype: float64
#
# Column: RESIDENTIAL UNITS
# RESIDENTIAL UNITS
# 1      41.067796
# 0      29.312343
# 2      18.982117
# 3       5.450158
# 4       1.591995
#          ...
# 179     0.001183
# 75      0.001183
# 193     0.001183
# 153     0.001183
# 128     0.001183
# Name: count, Length: 176, dtype: float64
#
# Column: COMMERCIAL UNITS
# COMMERCIAL UNITS
# 0       93.945451
# 1        4.208260
# 2        0.966315
# 3        0.306335
# 4        0.162038
# 5        0.087524
# 6        0.082793
# 7        0.036666
# 8        0.030752
# 9        0.023655
# 10       0.020107
# 12       0.014193
# 15       0.013010
# 11       0.011828
# 17       0.007097
# 14       0.007097
# 254      0.004731
# 20       0.004731
# 35       0.004731
# 13       0.004731
# 19       0.003548
# 42       0.003548
# 18       0.003548
# 22       0.003548
# 126      0.002366
# 25       0.002366
# 26       0.002366
# 436      0.002366
# 16       0.002366
# 422      0.002366
# 34       0.001183
# 172      0.001183
# 2261     0.001183
# 51       0.001183
# 184      0.001183
# 147      0.001183
# 28       0.001183
# 21       0.001183
# 32       0.001183
# 55       0.001183
# 56       0.001183
# 73       0.001183
# 31       0.001183
# 38       0.001183
# 59       0.001183
# 91       0.001183
# 30       0.001183
# 49       0.001183
# 24       0.001183
# 67       0.001183
# 318      0.001183
# 52       0.001183
# 23       0.001183
# 27       0.001183
# 62       0.001183
# Name: count, dtype: float64
#
# Column: TOTAL UNITS
# TOTAL UNITS
# 1      45.365946
# 0      23.373705
# 2      18.822444
# 3       6.401098
# 4       1.771775
#          ...
# 81      0.001183
# 179     0.001183
# 257     0.001183
# 82      0.001183
# 128     0.001183
# Name: count, Length: 192, dtype: float64
#
# Column: LAND SQUARE FEET
# LAND SQUARE FEET
# NaN        31.049818
# 0.0        12.213181
# 2000.0      4.635237
# 2500.0      4.104178
# 4000.0      3.600322
#              ...
# 5886.0      0.001183
# 76712.0     0.001183
# 6777.0      0.001183
# 10833.0     0.001183
# 10796.0     0.001183
# Name: count, Length: 6062, dtype: float64
#
# Column: GROSS SQUARE FEET
# GROSS SQUARE FEET
# NaN        32.658372
# 0.0        13.503572
# 2400.0      0.456545
# 1800.0      0.426976
# 2000.0      0.424611
#              ...
# 13740.0     0.001183
# 12256.0     0.001183
# 3823.0      0.001183
# 7768.0      0.001183
# 64117.0     0.001183
# Name: count, Length: 5691, dtype: float64
#
# Column: YEAR BUILT
# YEAR BUILT
# 0       8.243838
# 1920    7.149785
# 1930    5.964659
# 1925    5.100062
# 1910    4.240195
#           ...
# 1888    0.001183
# 1849    0.001183
# 1855    0.001183
# 1111    0.001183
# 1680    0.001183
# Name: count, Length: 158, dtype: float64
#
# Column: TAX CLASS AT TIME OF SALE
# TAX CLASS AT TIME OF SALE
# 1    49.123575
# 2    43.438047
# 4     7.433647
# 3     0.004731
# Name: count, dtype: float64
#
# Column: BUILDING CLASS AT TIME OF SALE
# BUILDING CLASS AT TIME OF SALE
# R4    15.362871
# D4    14.980839
# A1     7.984813
# A5     6.707432
# B2     5.816814
#         ...
# I3     0.001183
# R7     0.001183
# Q8     0.001183
# Y1     0.001183
# Z7     0.001183
# Name: count, Length: 166, dtype: float64
#
# Column: SALE PRICE
# SALE PRICE
# NaN          17.222170
# 0.0          12.097270
# 10.0          0.905994
# 450000.0      0.505039
# 550000.0      0.492028
#                ...
# 191100.0      0.001183
# 1542499.0     0.001183
# 782990.0      0.001183
# 2784765.0     0.001183
# 69300.0       0.001183
# Name: count, Length: 10008, dtype: float64
#
# Column: SALE DATE
# SALE DATE
# 2017-06-29    0.643421
# 2017-06-15    0.626863
# 2016-12-22    0.623315
# 2017-05-25    0.604390
# 2016-10-06    0.600842
#                 ...
# 2017-01-08    0.002366
# 2017-07-09    0.002366
# 2016-11-27    0.002366
# 2017-08-13    0.001183
# 2017-06-04    0.001183
# Name: count, Length: 364, dtype: float64

# %%
# --- Function to detect outliers using IQR ---
def detect_outliers_iqr(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = series[(series < lower_bound) | (series > upper_bound)]
    return outliers

# --- Analyze Outliers and Value Percentages for Numerical Columns ---
print("\n--- Outlier Analysis and Value Percentages (Numerical Columns) ---")
for col in numeric_cols_eda:
    plt.figure(figsize=(10, 6))
    sns.boxplot(y=df[col])
    plt.title(f'Box Plot of {col} (Outliers as Individual Points)')
    plt.ylabel(col)
    plt.show()

    outliers = detect_outliers_iqr(df[col])
    num_outliers = len(outliers)
    total_data_points = len(df[col])
    percentage_outliers = (num_outliers / total_data_points) * 100

    print(f"\nColumn: {col}")
    print(f"  Number of outliers (IQR): {num_outliers}")
    print(f"  Percentage of outliers: {percentage_outliers:.2f}%")
    if num_outliers > 0:
        print(f"  First few outlier values:\n{outliers.head()}")
    else:
        print("  No outliers detected (IQR).")

    print(f"\n  Percentage of each value in {col}:")
    value_counts = df[col].value_counts(dropna=False)
    percentages = (value_counts / total_data_points) * 100
    print(percentages.head()) # Display the top few percentages for brevity

# --- Calculate Value Percentages for Categorical Columns ---
categorical_cols_eda = df.select_dtypes(include='object').columns
print("\n--- Value Percentages (Categorical Columns) ---")
for col in categorical_cols_eda:
    print(f"\nColumn: {col}")
    total_data_points = len(df[col])
    value_counts = df[col].value_counts(dropna=False)
    percentages = (value_counts / total_data_points) * 100
    print(percentages.head()) # Display the top few percentages for brevity
# Out:
# --- Outlier Analysis and Value Percentages (Numerical Columns) ---
# Column: SALE PRICE
#   Number of outliers (IQR): 6652
#   Percentage of outliers: 7.87%
#   First few outlier values:
# 0     6625000.0
# 3     3936272.0
# 4     8000000.0
# 6     3192840.0
# 9    16232000.0
# Name: SALE PRICE, dtype: float64
#
#   Percentage of each value in SALE PRICE:
# SALE PRICE
# NaN         17.222170
# 0.0         12.097270
# 10.0         0.905994
# 450000.0     0.505039
# 550000.0     0.492028
# Name: count, dtype: float64
# Column: LAND SQUARE FEET
#   Number of outliers (IQR): 3571
#   Percentage of outliers: 4.22%
#   First few outlier values:
# 75     33650.0
# 196    32246.0
# 235    12344.0
# 239    10053.0
# 929     6468.0
# Name: LAND SQUARE FEET, dtype: float64
#
#   Percentage of each value in LAND SQUARE FEET:
# LAND SQUARE FEET
# NaN       31.049818
# 0.0       12.213181
# 2000.0     4.635237
# 2500.0     4.104178
# 4000.0     3.600322
# Name: count, dtype: float64
# Column: GROSS SQUARE FEET
#   Number of outliers (IQR): 4179
#   Percentage of outliers: 4.94%
#   First few outlier values:
# 0     6440.0
# 1    18690.0
# 2     7803.0
# 3     6794.0
# 5     9730.0
# Name: GROSS SQUARE FEET, dtype: float64
#
#   Percentage of each value in GROSS SQUARE FEET:
# GROSS SQUARE FEET
# NaN       32.658372
# 0.0       13.503572
# 2400.0     0.456545
# 1800.0     0.426976
# 2000.0     0.424611
# Name: count, dtype: float64
# Column: YEAR BUILT
#   Number of outliers (IQR): 7038
#   Percentage of outliers: 8.32%
#   First few outlier values:
# 74    0
# 76    0
# 77    0
# 78    0
# 87    0
# Name: YEAR BUILT, dtype: int64
#
#   Percentage of each value in YEAR BUILT:
# YEAR BUILT
# 0       8.243838
# 1920    7.149785
# 1930    5.964659
# 1925    5.100062
# 1910    4.240195
# Name: count, dtype: float64
#
# --- Value Percentages (Categorical Columns) ---
#
# Column: NEIGHBORHOOD
# NEIGHBORHOOD
# FLUSHING-NORTH             3.628708
# UPPER EAST SIDE (59-79)    2.053272
# UPPER EAST SIDE (79-96)    1.880589
# UPPER WEST SIDE (59-79)    1.701992
# BEDFORD STUYVESANT         1.698443
# Name: count, dtype: float64
#
# Column: BUILDING CLASS CATEGORY
# BUILDING CLASS CATEGORY
# 01 ONE FAMILY DWELLINGS                        21.567630
# 02 TWO FAMILY DWELLINGS                        18.720727
# 13 CONDOS - ELEVATOR APARTMENTS                15.362871
# 10 COOPS - ELEVATOR APARTMENTS                 15.259971
# 03 THREE FAMILY DWELLINGS                       5.185220
# Name: count, dtype: float64
#
# Column: TAX CLASS AT PRESENT
# TAX CLASS AT PRESENT
# 1     45.693571
# 2     36.569759
# 4      7.262147
# 2A     2.981738
# 2C     2.264986
# Name: count, dtype: float64
#
# Column: EASE-MENT
# EASE-MENT
#     100.0
# Name: count, dtype: float64
#
# Column: BUILDING CLASS AT PRESENT
# BUILDING CLASS AT PRESENT
# D4    14.977291
# R4    14.763211
# A1     7.987179
# A5     6.721626
# B2     5.822728
# Name: count, dtype: float64
#
# Column: ADDRESS
# ADDRESS
# 131-05 40TH   ROAD        0.248380
# 429 KENT AVENUE           0.186876
# 169 WEST 95TH   STREET    0.180962
# 131-03 40TH   ROAD        0.173866
# 265 STATE STREET          0.150211
# Name: count, dtype: float64
#
# Column: APARTMENT NUMBER
# APARTMENT NUMBER
#       77.466055
# 4      0.352463
# 3A     0.348914
# 2      0.325259
# 3B     0.325259
# Name: count, dtype: float64
#
# Column: BUILDING CLASS AT TIME OF SALE
# BUILDING CLASS AT TIME OF SALE
# R4    15.362871
# D4    14.980839
# A1     7.984813
# A5     6.707432
# B2     5.816814
# Name: count, dtype: float64
